# %% [markdown]
# ## 使用PyCaret建立红酒分类模型

# %%
import pandas as pd
import numpy as np

wine_df = pd.read_csv('winequality-red.csv', sep=';')

wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ### 将quality feature转为2分类（good or bad）

# %%
wine_df.quality = np.where(wine_df.quality >= 6,'Good', 'Bad')
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4     Bad
# 1      9.8     Bad
# 2      9.8     Bad
# 3      9.8    Good
# 4      9.4     Bad

# %% [markdown]
# ### 比较模型通过pycaret建立管道任务

# %%
from pycaret.classification import *

exp_clf101 = setup(data = wine_df, target = 'quality', session_id=123)
# Out:
# Setup Succesfully Completed!
# <style type="text/css">
# </style>
# <table id="T_55d58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55d58_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_55d58_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55d58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55d58_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_55d58_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55d58_row1_col0" class="data row1 col0" >Target Type</td>
#       <td id="T_55d58_row1_col1" class="data row1 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_55d58_row2_col0" class="data row2 col0" >Label Encoded</td>
#       <td id="T_55d58_row2_col1" class="data row2 col1" >Bad: 0, Good: 1</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_55d58_row3_col0" class="data row3 col0" >Original Data</td>
#       <td id="T_55d58_row3_col1" class="data row3 col1" >(1599, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_55d58_row4_col0" class="data row4 col0" >Missing Values </td>
#       <td id="T_55d58_row4_col1" class="data row4 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_55d58_row5_col0" class="data row5 col0" >Numeric Features </td>
#       <td id="T_55d58_row5_col1" class="data row5 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_55d58_row6_col0" class="data row6 col0" >Categorical Features </td>
#       <td id="T_55d58_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_55d58_row7_col0" class="data row7 col0" >Ordinal Features </td>
#       <td id="T_55d58_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_55d58_row8_col0" class="data row8 col0" >High Cardinality Features </td>
#       <td id="T_55d58_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_55d58_row9_col0" class="data row9 col0" >High Cardinality Method </td>
#       <td id="T_55d58_row9_col1" class="data row9 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_55d58_row10_col0" class="data row10 col0" >Sampled Data</td>
#       <td id="T_55d58_row10_col1" class="data row10 col1" >(1599, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_55d58_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_55d58_row11_col1" class="data row11 col1" >(1119, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_55d58_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_55d58_row12_col1" class="data row12 col1" >(480, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_55d58_row13_col0" class="data row13 col0" >Numeric Imputer </td>
#       <td id="T_55d58_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_55d58_row14_col0" class="data row14 col0" >Categorical Imputer </td>
#       <td id="T_55d58_row14_col1" class="data row14 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_55d58_row15_col0" class="data row15 col0" >Normalize </td>
#       <td id="T_55d58_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_55d58_row16_col0" class="data row16 col0" >Normalize Method </td>
#       <td id="T_55d58_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_55d58_row17_col0" class="data row17 col0" >Transformation </td>
#       <td id="T_55d58_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_55d58_row18_col0" class="data row18 col0" >Transformation Method </td>
#       <td id="T_55d58_row18_col1" class="data row18 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_55d58_row19_col0" class="data row19 col0" >PCA </td>
#       <td id="T_55d58_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_55d58_row20_col0" class="data row20 col0" >PCA Method </td>
#       <td id="T_55d58_row20_col1" class="data row20 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_55d58_row21_col0" class="data row21 col0" >PCA Components </td>
#       <td id="T_55d58_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_55d58_row22_col0" class="data row22 col0" >Ignore Low Variance </td>
#       <td id="T_55d58_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_55d58_row23_col0" class="data row23 col0" >Combine Rare Levels </td>
#       <td id="T_55d58_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_55d58_row24_col0" class="data row24 col0" >Rare Level Threshold </td>
#       <td id="T_55d58_row24_col1" class="data row24 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_55d58_row25_col0" class="data row25 col0" >Numeric Binning </td>
#       <td id="T_55d58_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_55d58_row26_col0" class="data row26 col0" >Remove Outliers </td>
#       <td id="T_55d58_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_55d58_row27_col0" class="data row27 col0" >Outliers Threshold </td>
#       <td id="T_55d58_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_55d58_row28_col0" class="data row28 col0" >Remove Multicollinearity </td>
#       <td id="T_55d58_row28_col1" class="data row28 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_55d58_row29_col0" class="data row29 col0" >Multicollinearity Threshold </td>
#       <td id="T_55d58_row29_col1" class="data row29 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_55d58_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_55d58_row30_col0" class="data row30 col0" >Clustering </td>
#       <td id="T_55d58_row30_col1" class="data row30 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_057fd th {
#   text-align: left;
# }
# #T_057fd_row0_col0, #T_057fd_row0_col2, #T_057fd_row0_col3, #T_057fd_row1_col0, #T_057fd_row1_col1, #T_057fd_row1_col3, #T_057fd_row1_col4, #T_057fd_row1_col5, #T_057fd_row1_col6, #T_057fd_row1_col7, #T_057fd_row2_col0, #T_057fd_row2_col1, #T_057fd_row2_col2, #T_057fd_row2_col3, #T_057fd_row2_col4, #T_057fd_row2_col5, #T_057fd_row2_col6, #T_057fd_row2_col7, #T_057fd_row3_col0, #T_057fd_row3_col1, #T_057fd_row3_col2, #T_057fd_row3_col3, #T_057fd_row3_col4, #T_057fd_row3_col5, #T_057fd_row3_col6, #T_057fd_row3_col7, #T_057fd_row4_col0, #T_057fd_row4_col1, #T_057fd_row4_col2, #T_057fd_row4_col3, #T_057fd_row4_col4, #T_057fd_row4_col5, #T_057fd_row4_col6, #T_057fd_row4_col7, #T_057fd_row5_col0, #T_057fd_row5_col1, #T_057fd_row5_col2, #T_057fd_row5_col3, #T_057fd_row5_col4, #T_057fd_row5_col5, #T_057fd_row5_col6, #T_057fd_row5_col7, #T_057fd_row6_col0, #T_057fd_row6_col1, #T_057fd_row6_col2, #T_057fd_row6_col3, #T_057fd_row6_col4, #T_057fd_row6_col5, #T_057fd_row6_col6, #T_057fd_row6_col7, #T_057fd_row7_col0, #T_057fd_row7_col1, #T_057fd_row7_col2, #T_057fd_row7_col3, #T_057fd_row7_col4, #T_057fd_row7_col5, #T_057fd_row7_col6, #T_057fd_row7_col7, #T_057fd_row8_col0, #T_057fd_row8_col1, #T_057fd_row8_col2, #T_057fd_row8_col3, #T_057fd_row8_col4, #T_057fd_row8_col5, #T_057fd_row8_col6, #T_057fd_row8_col7, #T_057fd_row9_col0, #T_057fd_row9_col1, #T_057fd_row9_col2, #T_057fd_row9_col3, #T_057fd_row9_col4, #T_057fd_row9_col5, #T_057fd_row9_col6, #T_057fd_row9_col7, #T_057fd_row10_col0, #T_057fd_row10_col1, #T_057fd_row10_col2, #T_057fd_row10_col3, #T_057fd_row10_col4, #T_057fd_row10_col5, #T_057fd_row10_col6, #T_057fd_row10_col7, #T_057fd_row11_col0, #T_057fd_row11_col1, #T_057fd_row11_col2, #T_057fd_row11_col3, #T_057fd_row11_col4, #T_057fd_row11_col5, #T_057fd_row11_col6, #T_057fd_row11_col7, #T_057fd_row12_col0, #T_057fd_row12_col1, #T_057fd_row12_col2, #T_057fd_row12_col3, #T_057fd_row12_col4, #T_057fd_row12_col5, #T_057fd_row12_col6, #T_057fd_row12_col7, #T_057fd_row13_col0, #T_057fd_row13_col1, #T_057fd_row13_col2, #T_057fd_row13_col4, #T_057fd_row13_col5, #T_057fd_row13_col6, #T_057fd_row13_col7 {
#   text-align: left;
# }
# #T_057fd_row0_col1, #T_057fd_row0_col4, #T_057fd_row0_col5, #T_057fd_row0_col6, #T_057fd_row0_col7, #T_057fd_row1_col2, #T_057fd_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_057fd_row0_col8, #T_057fd_row1_col8, #T_057fd_row2_col8, #T_057fd_row3_col8, #T_057fd_row5_col8, #T_057fd_row6_col8, #T_057fd_row7_col8, #T_057fd_row8_col8, #T_057fd_row9_col8, #T_057fd_row10_col8, #T_057fd_row11_col8, #T_057fd_row12_col8, #T_057fd_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_057fd_row4_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_057fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_057fd_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_057fd_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_057fd_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_057fd_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_057fd_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_057fd_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_057fd_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_057fd_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_057fd_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_057fd_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_057fd_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_057fd_row0_col1" class="data row0 col1" >0.8222</td>
#       <td id="T_057fd_row0_col2" class="data row0 col2" >0.8973</td>
#       <td id="T_057fd_row0_col3" class="data row0 col3" >0.8384</td>
#       <td id="T_057fd_row0_col4" class="data row0 col4" >0.8357</td>
#       <td id="T_057fd_row0_col5" class="data row0 col5" >0.8364</td>
#       <td id="T_057fd_row0_col6" class="data row0 col6" >0.6416</td>
#       <td id="T_057fd_row0_col7" class="data row0 col7" >0.6429</td>
#       <td id="T_057fd_row0_col8" class="data row0 col8" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_057fd_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_057fd_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_057fd_row1_col1" class="data row1 col1" >0.8159</td>
#       <td id="T_057fd_row1_col2" class="data row1 col2" >0.9044</td>
#       <td id="T_057fd_row1_col3" class="data row1 col3" >0.8319</td>
#       <td id="T_057fd_row1_col4" class="data row1 col4" >0.8302</td>
#       <td id="T_057fd_row1_col5" class="data row1 col5" >0.8306</td>
#       <td id="T_057fd_row1_col6" class="data row1 col6" >0.6290</td>
#       <td id="T_057fd_row1_col7" class="data row1 col7" >0.6299</td>
#       <td id="T_057fd_row1_col8" class="data row1 col8" >0.0640</td>
#     </tr>
#     <tr>
#       <th id="T_057fd_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_057fd_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_057fd_row2_col1" class="data row2 col1" >0.8132</td>
#       <td id="T_057fd_row2_col2" class="data row2 col2" >0.8849</td>
#       <td id="T_057fd_row2_col3" class="data row2 col3" >0.8204</td>
#       <td id="T_057fd_row2_col4" class="data row2 col4" >0.8346</td>
#       <td id="T_057fd_row2_col5" class="data row2 col5" >0.8266</td>
#       <td id="T_057fd_row2_col6" class="data row2 col6" >0.6242</td>
#       <td id="T_057fd_row2_col7" class="data row2 col7" >0.6257</td>
#       <td id="T_057fd_row2_col8" class="data row2 col8" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_057fd_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_057fd_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_057fd_row3_col1" class="data row3 col1" >0.7855</td>
#       <td id="T_057fd_row3_col2" class="data row3 col2" >0.8593</td>
#       <td id="T_057fd_row3_col3" class="data row3 col3" >0.7990</td>
#       <td id="T_057fd_row3_col4" class="data row3 col4" >0.8071</td>
#       <td id="T_057fd_row3_col5" class="data row3 col5" >0.8018</td>
#       <td id="T_057fd_row3_col6" class="data row3 col6" >0.5682</td>
#       <td id="T_057fd_row3_col7" class="data row3 col7" >0.5703</td>
#       <td id="T_057fd_row3_col8" class="data row3 col8" >0.0370</td>
#     </tr>
#     <tr>
#       <th id="T_057fd_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_057fd_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_057fd_row4_col1" class="data row4 col1" >0.7569</td>
#       <td id="T_057fd_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_057fd_row4_col3" class="data row4 col3" >0.7497</td>
#       <td id="T_057fd_row4_col4" class="data row4 col4" >0.7910</td>
#       <td id="T_057fd_row4_col5" class="data row4 col5" >0.7688</td>
#       <td id="T_057fd_row4_col6" class="data row4 col6" >0.5131</td>
#       <td id="T_057fd_row4_col7" class="data row4 col7" >0.5151</td>
#       <td id="T_057fd_row4_col8" class="data row4 col8" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_057fd_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_057fd_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_057fd_row5_col1" class="data row5 col1" >0.7515</td>
#       <td id="T_057fd_row5_col2" class="data row5 col2" >0.8177</td>
#       <td id="T_057fd_row5_col3" class="data row5 col3" >0.7480</td>
#       <td id="T_057fd_row5_col4" class="data row5 col4" >0.7837</td>
#       <td id="T_057fd_row5_col5" class="data row5 col5" >0.7648</td>
#       <td id="T_057fd_row5_col6" class="data row5 col6" >0.5019</td>
#       <td id="T_057fd_row5_col7" class="data row5 col7" >0.5033</td>
#       <t

# %% [markdown]
# #### 归一化数据尝试第二次

# %%
exp_clf102 = setup(data = wine_df, target = 'quality', session_id=123,
                  normalize = True, 
                  transformation = True)
# Out:
# Setup Succesfully Completed!
# <style type="text/css">
# #T_680bb_row15_col1, #T_680bb_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_680bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_680bb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_680bb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_680bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_680bb_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_680bb_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_680bb_row1_col0" class="data row1 col0" >Target Type</td>
#       <td id="T_680bb_row1_col1" class="data row1 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_680bb_row2_col0" class="data row2 col0" >Label Encoded</td>
#       <td id="T_680bb_row2_col1" class="data row2 col1" >Bad: 0, Good: 1</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_680bb_row3_col0" class="data row3 col0" >Original Data</td>
#       <td id="T_680bb_row3_col1" class="data row3 col1" >(1599, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_680bb_row4_col0" class="data row4 col0" >Missing Values </td>
#       <td id="T_680bb_row4_col1" class="data row4 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_680bb_row5_col0" class="data row5 col0" >Numeric Features </td>
#       <td id="T_680bb_row5_col1" class="data row5 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_680bb_row6_col0" class="data row6 col0" >Categorical Features </td>
#       <td id="T_680bb_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_680bb_row7_col0" class="data row7 col0" >Ordinal Features </td>
#       <td id="T_680bb_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_680bb_row8_col0" class="data row8 col0" >High Cardinality Features </td>
#       <td id="T_680bb_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_680bb_row9_col0" class="data row9 col0" >High Cardinality Method </td>
#       <td id="T_680bb_row9_col1" class="data row9 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_680bb_row10_col0" class="data row10 col0" >Sampled Data</td>
#       <td id="T_680bb_row10_col1" class="data row10 col1" >(1599, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_680bb_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_680bb_row11_col1" class="data row11 col1" >(1119, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_680bb_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_680bb_row12_col1" class="data row12 col1" >(480, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_680bb_row13_col0" class="data row13 col0" >Numeric Imputer </td>
#       <td id="T_680bb_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_680bb_row14_col0" class="data row14 col0" >Categorical Imputer </td>
#       <td id="T_680bb_row14_col1" class="data row14 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_680bb_row15_col0" class="data row15 col0" >Normalize </td>
#       <td id="T_680bb_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_680bb_row16_col0" class="data row16 col0" >Normalize Method </td>
#       <td id="T_680bb_row16_col1" class="data row16 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_680bb_row17_col0" class="data row17 col0" >Transformation </td>
#       <td id="T_680bb_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_680bb_row18_col0" class="data row18 col0" >Transformation Method </td>
#       <td id="T_680bb_row18_col1" class="data row18 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_680bb_row19_col0" class="data row19 col0" >PCA </td>
#       <td id="T_680bb_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_680bb_row20_col0" class="data row20 col0" >PCA Method </td>
#       <td id="T_680bb_row20_col1" class="data row20 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_680bb_row21_col0" class="data row21 col0" >PCA Components </td>
#       <td id="T_680bb_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_680bb_row22_col0" class="data row22 col0" >Ignore Low Variance </td>
#       <td id="T_680bb_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_680bb_row23_col0" class="data row23 col0" >Combine Rare Levels </td>
#       <td id="T_680bb_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_680bb_row24_col0" class="data row24 col0" >Rare Level Threshold </td>
#       <td id="T_680bb_row24_col1" class="data row24 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_680bb_row25_col0" class="data row25 col0" >Numeric Binning </td>
#       <td id="T_680bb_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_680bb_row26_col0" class="data row26 col0" >Remove Outliers </td>
#       <td id="T_680bb_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_680bb_row27_col0" class="data row27 col0" >Outliers Threshold </td>
#       <td id="T_680bb_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_680bb_row28_col0" class="data row28 col0" >Remove Multicollinearity </td>
#       <td id="T_680bb_row28_col1" class="data row28 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_680bb_row29_col0" class="data row29 col0" >Multicollinearity Threshold </td>
#       <td id="T_680bb_row29_col1" class="data row29 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_680bb_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_680bb_row30_col0" class="data row30 col0" >Clustering </td>
#       <td id="T_680bb

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_e6339 th {
#   text-align: left;
# }
# #T_e6339_row0_col0, #T_e6339_row1_col0, #T_e6339_row1_col1, #T_e6339_row1_col2, #T_e6339_row1_col3, #T_e6339_row1_col4, #T_e6339_row1_col5, #T_e6339_row1_col6, #T_e6339_row1_col7, #T_e6339_row2_col0, #T_e6339_row2_col1, #T_e6339_row2_col2, #T_e6339_row2_col3, #T_e6339_row2_col4, #T_e6339_row2_col5, #T_e6339_row2_col6, #T_e6339_row2_col7, #T_e6339_row3_col0, #T_e6339_row3_col1, #T_e6339_row3_col2, #T_e6339_row3_col3, #T_e6339_row3_col4, #T_e6339_row3_col5, #T_e6339_row3_col6, #T_e6339_row3_col7, #T_e6339_row4_col0, #T_e6339_row4_col1, #T_e6339_row4_col2, #T_e6339_row4_col3, #T_e6339_row4_col4, #T_e6339_row4_col5, #T_e6339_row4_col6, #T_e6339_row4_col7, #T_e6339_row5_col0, #T_e6339_row5_col1, #T_e6339_row5_col2, #T_e6339_row5_col3, #T_e6339_row5_col4, #T_e6339_row5_col5, #T_e6339_row5_col6, #T_e6339_row5_col7, #T_e6339_row6_col0, #T_e6339_row6_col1, #T_e6339_row6_col2, #T_e6339_row6_col3, #T_e6339_row6_col4, #T_e6339_row6_col5, #T_e6339_row6_col6, #T_e6339_row6_col7, #T_e6339_row7_col0, #T_e6339_row7_col1, #T_e6339_row7_col2, #T_e6339_row7_col3, #T_e6339_row7_col4, #T_e6339_row7_col5, #T_e6339_row7_col6, #T_e6339_row7_col7, #T_e6339_row8_col0, #T_e6339_row8_col1, #T_e6339_row8_col2, #T_e6339_row8_col3, #T_e6339_row8_col4, #T_e6339_row8_col5, #T_e6339_row8_col6, #T_e6339_row8_col7, #T_e6339_row9_col0, #T_e6339_row9_col1, #T_e6339_row9_col2, #T_e6339_row9_col3, #T_e6339_row9_col4, #T_e6339_row9_col5, #T_e6339_row9_col6, #T_e6339_row9_col7, #T_e6339_row10_col0, #T_e6339_row10_col1, #T_e6339_row10_col2, #T_e6339_row10_col3, #T_e6339_row10_col4, #T_e6339_row10_col5, #T_e6339_row10_col6, #T_e6339_row10_col7, #T_e6339_row11_col0, #T_e6339_row11_col1, #T_e6339_row11_col2, #T_e6339_row11_col3, #T_e6339_row11_col4, #T_e6339_row11_col5, #T_e6339_row11_col6, #T_e6339_row11_col7, #T_e6339_row12_col0, #T_e6339_row12_col1, #T_e6339_row12_col2, #T_e6339_row12_col3, #T_e6339_row12_col4, #T_e6339_row12_col5, #T_e6339_row12_col6, #T_e6339_row12_col7, #T_e6339_row13_col0, #T_e6339_row13_col1, #T_e6339_row13_col2, #T_e6339_row13_col3, #T_e6339_row13_col4, #T_e6339_row13_col5, #T_e6339_row13_col6, #T_e6339_row13_col7, #T_e6339_row14_col0, #T_e6339_row14_col1, #T_e6339_row14_col2, #T_e6339_row14_col3, #T_e6339_row14_col4, #T_e6339_row14_col5, #T_e6339_row14_col6, #T_e6339_row14_col7 {
#   text-align: left;
# }
# #T_e6339_row0_col1, #T_e6339_row0_col2, #T_e6339_row0_col3, #T_e6339_row0_col4, #T_e6339_row0_col5, #T_e6339_row0_col6, #T_e6339_row0_col7 {
#   background-color: yellow;
#   text-align: left;
# }
# #T_e6339_row0_col8, #T_e6339_row1_col8, #T_e6339_row2_col8, #T_e6339_row3_col8, #T_e6339_row4_col8, #T_e6339_row5_col8, #T_e6339_row6_col8, #T_e6339_row7_col8, #T_e6339_row8_col8, #T_e6339_row9_col8, #T_e6339_row10_col8, #T_e6339_row11_col8, #T_e6339_row12_col8, #T_e6339_row13_col8, #T_e6339_row14_col8 {
#   background-color: lightgrey;
#   text-align: left;
# }
# </style>
# <table id="T_e6339">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6339_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e6339_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e6339_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e6339_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e6339_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e6339_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e6339_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e6339_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_e6339_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6339_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6339_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_e6339_row0_col1" class="data row0 col1" >0.8079</td>
#       <td id="T_e6339_row0_col2" class="data row0 col2" >0.8890</td>
#       <td id="T_e6339_row0_col3" class="data row0 col3" >0.8230</td>
#       <td id="T_e6339_row0_col4" class="data row0 col4" >0.8200</td>
#       <td id="T_e6339_row0_col5" class="data row0 col5" >0.8206</td>
#       <td id="T_e6339_row0_col6" class="data row0 col6" >0.6138</td>
#       <td id="T_e6339_row0_col7" class="data row0 col7" >0.6155</td>
#       <td id="T_e6339_row0_col8" class="data row0 col8" >0.1337</td>
#     </tr>
#     <tr>
#       <th id="T_e6339_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6339_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_e6339_row1_col1" class="data row1 col1" >0.7900</td>
#       <td id="T_e6339_row1_col2" class="data row1 col2" >0.8718</td>
#       <td id="T_e6339_row1_col3" class="data row1 col3" >0.8112</td>
#       <td id="T_e6339_row1_col4" class="data row1 col4" >0.8022</td>
#       <td id="T_e6339_row1_col5" class="data row1 col5" >0.8054</td>
#       <td id="T_e6339_row1_col6" class="data row1 col6" >0.5774</td>
#       <td id="T_e6339_row1_col7" class="data row1 col7" >0.5797</td>
#       <td id="T_e6339_row1_col8" class="data row1 col8" >0.1784</td>
#     </tr>
#     <tr>
#       <th id="T_e6339_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e6339_row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_e6339_row2_col1" class="data row2 col1" >0.7882</td>
#       <td id="T_e6339_row2_col2" class="data row2 col2" >0.8628</td>
#       <td id="T_e6339_row2_col3" class="data row2 col3" >0.7929</td>
#       <td id="T_e6339_row2_col4" class="data row2 col4" >0.8098</td>
#       <td id="T_e6339_row2_col5" class="data row2 col5" >0.7998</td>
#       <td id="T_e6339_row2_col6" class="data row2 col6" >0.5751</td>
#       <td id="T_e6339_row2_col7" class="data row2 col7" >0.5774</td>
#       <td id="T_e6339_row2_col8" class="data row2 col8" >2.1053</td>
#     </tr>
#     <tr>
#       <th id="T_e6339_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e6339_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e6339_row3_col1" class="data row3 col1" >0.7793</td>
#       <td id="T_e6339_row3_col2" class="data row3 col2" >0.8686</td>
#       <td id="T_e6339_row3_col3" class="data row3 col3" >0.7962</td>
#       <td id="T_e6339_row3_col4" class="data row3 col4" >0.7935</td>
#       <td id="T_e6339_row3_col5" class="data row3 col5" >0.7939</td>
#       <td id="T_e6339_row3_col6" class="data row3 col6" >0.5564</td>
#       <td id="T_e6339_row3_col7" class="data row3 col7" >0.5580</td>
#       <td id="T_e6339_row3_col8" class="data row3 col8" >0.1084</td>
#     </tr>
#     <tr>
#       <th id="T_e6339_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e6339_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_e6339_row4_col1" class="data row4 col1" >0.7676</td>
#       <td id="T_e6339_row4_col2" class="data row4 col2" >0.8451</td>
#       <td id="T_e6339_row4_col3" class="data row4 col3" >0.7577</td>
#       <td id="T_e6339_row4_col4" class="data row4 col4" >0.8011</td>
#       <td id="T_e6339_row4_col5" class="data row4 col5" >0.7772</td>
#       <td id="T_e6339_row4_col6" class="data row4 col6" >0.5347</td>
#       <td id="T_e6339_row4_col7" class="data row4 col7" >0.5380</td>
#       <td id="T_e6339_row4_col8" class="data row4 col8" >0.0278</td>
#     </tr>
#     <tr>
#       <th id="T_e6339_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e6339_row5_col0" class="data row5 col0" >Gradient Boosting Classifier</td>
#       <td id="T_e6339_row5_col1" class="data row5 col1" >0.7659</td>
#       <td id="T_e6339_row5_col2" class="data row5 col2" >0.8493</td>
#       <td id="T_e6339_row5_col3" class="data row5 col3" >0.7762</td>
#       <td id="T_e6339_row5_col4" class="data row5 col4" >0.7881</td>
#       <td id="T_e6339_row5_col5" class="data row5 col5" >0.7800</td>
#       <td id="T_e6339_row5_col6" class="data r

# %% [markdown]
# ### 选择最好的ExtraTree作为分类器，并创建实例

# %%
et_model = create_model('et')
# Out:
# <style type="text/css">
# #T_5b73c_row10_col0, #T_5b73c_row10_col1, #T_5b73c_row10_col2, #T_5b73c_row10_col3, #T_5b73c_row10_col4, #T_5b73c_row10_col5, #T_5b73c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5b73c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b73c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5b73c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5b73c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5b73c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5b73c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5b73c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5b73c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b73c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b73c_row0_col0" class="data row0 col0" >0.8393</td>
#       <td id="T_5b73c_row0_col1" class="data row0 col1" >0.9224</td>
#       <td id="T_5b73c_row0_col2" class="data row0 col2" >0.8500</td>
#       <td id="T_5b73c_row0_col3" class="data row0 col3" >0.8500</td>
#       <td id="T_5b73c_row0_col4" class="data row0 col4" >0.8500</td>
#       <td id="T_5b73c_row0_col5" class="data row0 col5" >0.6769</td>
#       <td id="T_5b73c_row0_col6" class="data row0 col6" >0.6769</td>
#     </tr>
#     <tr>
#       <th id="T_5b73c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b73c_row1_col0" class="data row1 col0" >0.8036</td>
#       <td id="T_5b73c_row1_col1" class="data row1 col1" >0.8816</td>
#       <td id="T_5b73c_row1_col2" class="data row1 col2" >0.8000</td>
#       <td id="T_5b73c_row1_col3" class="data row1 col3" >0.8276</td>
#       <td id="T_5b73c_row1_col4" class="data row1 col4" >0.8136</td>
#       <td id="T_5b73c_row1_col5" class="data row1 col5" >0.6061</td>
#       <td id="T_5b73c_row1_col6" class="data row1 col6" >0.6065</td>
#     </tr>
#     <tr>
#       <th id="T_5b73c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b73c_row2_col0" class="data row2 col0" >0.6875</td>
#       <td id="T_5b73c_row2_col1" class="data row2 col1" >0.7675</td>
#       <td id="T_5b73c_row2_col2" class="data row2 col2" >0.7167</td>
#       <td id="T_5b73c_row2_col3" class="data row2 col3" >0.7049</td>
#       <td id="T_5b73c_row2_col4" class="data row2 col4" >0.7107</td>
#       <td id="T_5b73c_row2_col5" class="data row2 col5" >0.3710</td>
#       <td id="T_5b73c_row2_col6" class="data row2 col6" >0.3710</td>
#     </tr>
#     <tr>
#       <th id="T_5b73c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b73c_row3_col0" class="data row3 col0" >0.8214</td>
#       <td id="T_5b73c_row3_col1" class="data row3 col1" >0.8864</td>
#       <td id="T_5b73c_row3_col2" class="data row3 col2" >0.8500</td>
#       <td id="T_5b73c_row3_col3" class="data row3 col3" >0.8226</td>
#       <td id="T_5b73c_row3_col4" class="data row3 col4" >0.8361</td>
#       <td id="T_5b73c_row3_col5" class="data row3 col5" >0.6401</td>
#       <td id="T_5b73c_row3_col6" class="data row3 col6" >0.6405</td>
#     </tr>
#     <tr>
#       <th id="T_5b73c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b73c_row4_col0" class="data row4 col0" >0.7589</td>
#       <td id="T_5b73c_row4_col1" class="data row4 col1" >0.8651</td>
#       <td id="T_5b73c_row4_col2" class="data row4 col2" >0.7333</td>
#       <td id="T_5b73c_row4_col3" class="data row4 col3" >0.8000</td>
#       <td id="T_5b73c_row4_col4" class="data row4 col4" >0.7652</td>
#       <td id="T_5b73c_row4_col5" class="data row4 col5" >0.5185</td>
#       <td id="T_5b73c_row4_col6" class="data row4 col6" >0.5205</td>
#     </tr>
#     <tr>
#       <th id="T_5b73c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5b73c_row5_col0" class="data row5 col0" >0.7857</td>
#       <td id="T_5b73c_row5_col1" class="data row5 col1" >0.8715</td>
#       <td id="T_5b73c_row5_col2" class="data row5 col2" >0.8000</td>
#       <td id="T_5b73c_row5_col3" class="data row5 col3" >0.8000</td>
#       <td id="T_5b73c_row5_col4" class="data row5 col4" >0.8000</td>
#       <td id="T_5b73c_row5_col5" class="data row5 col5" >0.5692</td>
#       <td id="T_5b73c_row5_col6" class="data row5 col6" >0.5692</td>
#     </tr>
#     <tr>
#       <th id="T_5b73c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5b73c_row6_col0" class="data row6 col0" >0.8571</td>
#       <td id="T_5b73c_row6_col1" class="data row6 col1" >0.9207</td>
#       <td id="T_5b73c_row6_col2" class="data row6 col2" >0.8667</td>
#       <td id="T_5b73c_row6_col3" class="data row6 col3" >0.8667</td>
#       <td id="T_5b73c_row6_col4" class="data row6 col4" >0.8667</td>
#       <td id="T_5b73c_row6_col5" class="data row6 col5" >0.7128</td>
#       <td id="T_5b73c_row6_col6" class="data row6 col6" >0.7128</td>
#     </tr>
#     <tr>
#       <th id="T_5b73c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5b73c_row7_col0" class="data row7 col0" >0.8661</td>
#       <td id="T_5b73c_row7_col1" class="data row7 col1" >0.9447</td>
#       <td id="T_5b73c_row7_col2" class="data row7 col2" >0.8333</td>
#       <td id="T_5b73c_row7_col3" class="data row7 col3" >0.9091</td>
#       <td id="T_5b73c_row7_col4" class="data row7 col4" >0.8696</td>
#       <td id="T_5b73c_row7_col5" class="data row7 col5" >0.7325</td>
#       <td id="T_5b73c_row7_col6" class="data row7 col6" >0.7354</td>
#     </tr>
#     <tr>
#       <th id="T_5b73c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5b73c_row8_col0" class="data row8 col0" >0.8393</td>
#       <td id="T_5b73c_row8_col1" class="data row8 col1" >0.9041</td>
#       <td id="T_5b73c_row8_col2" class="data row8 col2" >0.8644</td>
#       <td id="T_5b73c_row8_col3" class="data row8 col3" >0.8361</td>
#       <td id="T_5b73c_row8_col4" class="data row8 col4" >0.8500</td>
#       <td id="T_5b73c_row8_col5" class="data row8 col5" >0.6770</td>
#       <td id="T_5b73c_row8_col6" class="data row8 col6" >0.6775</td>
#     </tr>
#     <tr>
#       <th id="T_5b73c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5b73c_row9_col0" class="data row9 col0" >0.8198</td>
#       <td id="T_5b73c_row9_col1" class="data row9 col1" >0.9258</td>
#       <td id="T_5b73c_row9_col2" class="data row9 col2" >0.9153</td>
#       <td id="T_5b73c_row9_col3" class="data row9 col3" >0.7826</td>
#       <td id="T_5b73c_row9_col4" class="data row9 col4" >0.8437</td>
#       <td id="T_5b73c_row9_col5" class="data row9 col5" >0.6340</td>
#       <td id="T_5b73c_row9_col6" class="data row9 col6" >0.6449</td>
#     </tr>
#     <tr>
#       <th id="T_5b73c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5b73c_row10_col0" class="data row10 col0" >0.8079</td>
#       <td id="T_5b73c_row10_col1" class="data row10 col1" >0.8890</td>
#       <td id="T_5b73c_row10_col2" class="data row10 col2" >0.8230</td>
#       <td id="T_5b73c_row10_col3" class="data row10 col3" >0.8200</td>
#       <td id="T_5b73c_row10_col4" class="data row10 col4" >0.8206</td>
#       <td id="T_5b73c_row10_col5" class="data row10 col5" >0.6138</td>
#       <td id="T_5b73c_row10_col6" class="data row10 col6" >0.6155</td>
#     </tr>
#     <tr>
#       <th id="T_5b73c_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_5b73c_row11_col0" class="data row11 col0" >0.0505</td>
#       <td id="T_5b73c_row11_col1" class="data row11 col1" >0.0475</td>
#       <td id="T_5b73c_row11_col2" class="data row11 col2" >0.0584</td>
#       <td id="T_5b73c_row11_col3" class="data row11 col3" >0.0517</td>
#       <td id="T_5b73c_row11_col4" class="data row11 col4" >0.0476</td>
#       <td id="T_5b73c_row11_col5" class="data row11 col5" >0.1015</td>
#       <td id="T_5b73c_row11_col6" class="data row11 col6" >0.1020</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### 对该模型进行可视化评估

# %%
evaluate_model(et_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### 在验证集上验证，观察效果

# %%
predict_model(et_model)
# Out:
#                     Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# 0  Extra Trees Classifier    0.8146  0.8983  0.8288  0.8256  0.8272  0.6272
#
#       MCC
# 0  0.6272
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0        -0.005604          0.394596     0.136158        1.140747  -0.747088
# 1        -0.769331          0.600717    -0.999232       -0.883571  -0.126655
# 2         0.249192          1.056111    -0.293609        0.344431  -0.126655
# 3        -0.522435          0.063170     0.336652       -0.184197  -0.482036
# 4        -0.443413          2.926164    -1.502162        1.623971   0.754724
# ..             ...               ...          ...             ...        ...
# 475       0.678236          0.177116     0.287344        0.185945   1.145283
# 476      -0.443413         -0.968102     0.187128        0.612182   0.399926
# 477       1.888491         -0.692787     1.199605       -0.397363  -1.267137
# 478      -1.495902          0.650741     0.287344       -1.158059   0.440161
# 479       0.578937         -0.760635     0.715050       -2.481655  -2.635054
#
#      free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0               0.742605              1.668267  0.302880 -0.576412  -0.792626
# 1              -0.796673             -0.707976  0.565035  1.088545  -0.904344
# 2              -0.479653             -0.003577  0.329166  0.019022   0.145317
# 3               2.201986              0.964234 -1.371097  0.212476   1.130120
# 4              -1.325466             -1.326805 -0.067088  1.995006  -0.792626
# ..                   ...                   ...       ...       ...        ...
# 475            -0.332051             -0.003577  0.139514 -0.442392  -0.578801
# 476             1.089754              1.006003 -0.146889  0.529757   0.426514
# 477            -1.142205             -0.707976  1.395468 -1.814347  -0.190145
# 478             0.183230              0.830077  0.091949  0.965523   1.003909
# 479             1.026115              0.447616 -1.045039 -0.711262   1.170071
#
#       alcohol quality Label  Score
# 0   -1.086355    Good   Bad   0.17
# 1   -1.749849     Bad   Bad   0.31
# 2   -1.086355     Bad   Bad   0.22
# 3    1.826208    Good  Good   0.91
# 4    0.494160     Bad   Bad   0.08
# ..        ...     ...   ...    ...
# 475  0.658770     Bad   Bad   0.46
# 476  0.735837     Bad  Good   0.83
# 477 -1.245039    Good  Good   0.67
# 478 -1.245039     Bad   Bad   0.37
# 479  0.658770    Good  Good   0.83
#
# [480 rows x 14 columns]

# %% [markdown]
# ### finalize_model 结束过程

# %%
finalize_model(et_model)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)

# %% [markdown]
# ### 保存模型到本地化pickle文件

# %%
save_model(et_model, model_name = 'extra_tree_model')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %% [markdown]
# ## 测试是否能够上线

# %%
from pycaret.classification import load_model, predict_model
import streamlit as st
import pandas as pd
import numpy as np
# Out:
# 2022-04-03 13:38:08.004 INFO    numexpr.utils: Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2022-04-03 13:38:08.005 INFO    numexpr.utils: NumExpr defaulting to 8 threads.

# %%
def predict_quality(model, df):
    
    predictions_data = predict_model(estimator = model, data = df)
    
    return predictions_data['Label'][0]
    
model = load_model('extra_tree_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
features = {'fixed acidity': 10, 'volatile acidity': 1,
            'citric acid': 0.38, 'residual sugar': 5.9,
            'chlorides': 0.638, 'free sulfur dioxide': 51,
            'total sulfur dioxide': 144, 'density': 0.99,
            'pH': 3, 'sulphates': 0.5, 'alcohol': 10.5
            }
 

features_df  = pd.DataFrame([features])
features_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             10                 1         0.38             5.9      0.638
#
#    free sulfur dioxide  total sulfur dioxide  density  pH  sulphates  alcohol
# 0                   51                   144     0.99   3        0.5     10.5

# %%
prediction = predict_quality(model, features_df)

# %%
str(prediction)
# Out:
# 'Good'

# %%
# !streamlit run streamlit_app.py
# Out:
# ^C
